# %%
import requests, json

# %%
apiKey = "cabdbda40038ba7d1165b953b1c7bd6c"
apiUrl = f"https://api.openweathermap.org/data/2.5/onecall?lat={lat}&lon={lon}&appid={apiKey}&units=metric"

# %%
lat= 51.5085
lon= -0.125

# %%
result=requests.get(apiUrl).text
result
# Out:
# '{"lat":51.5073,"lon":-0.1276,"timezone":"Europe/London","timezone_offset":3600,"current":{"dt":1690317499,"sunrise":1690258399,"sunset":1690315226,"temp":16.57,"feels_like":15.88,"pressure":1011,"humidity":61,"dew_point":9.03,"uvi":0,"clouds":83,"visibility":10000,"wind_speed":3.6,"wind_deg":300,"weather":[{"id":803,"main":"Clouds","description":"broken clouds","icon":"04n"}]},"minutely":[{"dt":1690317540,"precipitation":0},{"dt":1690317600,"precipitation":0},{"dt":1690317660,"precipitation":0},{"dt":1690317720,"precipitation":0},{"dt":1690317780,"precipitation":0},{"dt":1690317840,"precipitation":0},{"dt":1690317900,"precipitation":0},{"dt":1690317960,"precipitation":0},{"dt":1690318020,"precipitation":0},{"dt":1690318080,"precipitation":0},{"dt":1690318140,"precipitation":0},{"dt":1690318200,"precipitation":0},{"dt":1690318260,"precipitation":0},{"dt":1690318320,"precipitation":0},{"dt":1690318380,"precipitation":0},{"dt":1690318440,"precipitation":0},{"dt":1690318500,"precipitati
# ...

# %%
dict_result=json.loads(result)[0]

# %%
your key is invalid
# Out:
# 'France'

# %% [markdown]
# go back where you were before i dont trust your wifi, we can end call
